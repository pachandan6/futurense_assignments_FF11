# %%
import time
import threading
def fun(name,delay):
    counter=0
    while counter <5:
        print(name)
        print(time.ctime())
        time.sleep(delay)
        counter+=1

    
t1=threading.Thread(target=fun,args=("dhoni",2))
t2=threading.Thread(target=fun,args=("kohli",4))
t1.start()
t2.start()
# Out:
# dhoni
# Thu May  5 15:52:25 2022
# kohli
# Thu May  5 15:52:25 2022
# dhoni
# Thu May  5 15:52:27 2022
# kohlidhoni
# Thu May  5 15:52:29 2022
#
# Thu May  5 15:52:29 2022
# dhoni
# Thu May  5 15:52:31 2022
# kohli
# Thu May  5 15:52:33 2022
# dhoni
# Thu May  5 15:52:33 2022
# kohli
# Thu May  5 15:52:37 2022
# kohli
# Thu May  5 15:52:41 2022

# %%
#Assignment 
#implement pdf encryption in threads

# %%
from PyPDF2 import PdfFileWriter, PdfFileReader
from datetime import datetime
import threading
import os

# %%
namefile=""
num_of_pages=0


#function to check whether the pdf is encrypted or not  
import os
files=os.listdir("/Users/pachandan/1_Futurense_dailywork/Day1/pdffiles")

def pdfencrypt():
    #print(i)
    pdfFileObj = open('/Users/pachandan/1_Futurense_dailywork/Day1/pdffiles/July018.pdf', 'rb')
    out=PdfFileWriter()
    pdfReader = PyPDF2.PdfFileReader(pdfFileObj)
    num = pdfReader.numPages
    print(num)

for i in files:
    t1=threading.Thread(target=pdfencrypt)
    t1.start()
    t1.join()
# Out:
# Exception in thread Thread-22:
# Traceback (most recent call last):
#   File "/Users/pachandan/opt/anaconda3/lib/python3.8/threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "/Users/pachandan/opt/anaconda3/lib/python3.8/threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-3-d00bde0eaf42>", line 19, in pdfencrypt
# NameError: name 'PyPDF2' is not defined
# Exception in thread Thread-23:
# Traceback (most recent call last):
#   File "/Users/pachandan/opt/anaconda3/lib/python3.8/threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "/Users/pachandan/opt/anaconda3/lib/python3.8/threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-3-d00bde0eaf42>", line 19, in pdfencrypt
# NameError: name 'PyPDF2' is not defined
# Exception in thread Thread-24:
# Traceback (most recent call last):
# ...
